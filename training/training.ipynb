# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "SB-FishDisease",
    shuffle=True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 352 files belonging to 7 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial Red disease',
#  'Bacterial diseases - Aeromoniasis',
#  'Bacterial gill disease',
#  'Fungal diseases Saprolegniasis',
#  'Healthy Fish',
#  'Parasitic diseases',
#  'Viral diseases White tail disease']

# %%
for image_batch, label_batch in dataset.take(1):
    plt.title(class_names[label_batch[0]])
    plt.imshow(image_batch[2].numpy().astype("uint8"))
    plt.axis("off")

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 8.8

# %%
train_ds = dataset.take(8)
len(train_ds)
# Out:
# 8

# %%
test_ds = dataset.skip(8)
len(test_ds)
# Out:
# 3

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 1.1

# %%
val_ds = test_ds.take(1)
len(val_ds)
# Out:
# 1

# %%
test_ds = test_ds.skip(1)
len(test_ds)
# Out:
# 2

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 8

# %%
len(val_ds)
# Out:
# 1

# %%
len(test_ds)
# Out:
# 2

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes=7
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(64, (3,3), activation='relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(72,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(72,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(72, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(72, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(72, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(72, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 224, 224, 3)         0
#
#  sequential_1 (Sequential)   (32, 224, 224, 3)         0
#
#  conv2d (Conv2D)             (32, 222, 222, 64)        1792
#
#  max_pooling2d (MaxPooling2  (32, 111, 111, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 109, 109, 72)        41544
#
#  max_pooling2d_1 (MaxPoolin  (32, 54, 54, 72)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 52, 52, 72)          46728
#
#  max_pooling2d_2 (MaxPoolin  (32, 26, 26, 72)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 24, 24, 72)          46728
#
#  max_pooling2d_3 (MaxPoolin  (32, 12, 12, 72)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 10, 10, 72)          46728
#
#  max_pooling2d_4 (MaxPoolin  (32, 5, 5, 72)            0
#  g2D)
#
#  conv2d_5 (Conv2D)           (32, 3, 3, 72)            46728
#
#  max_pooling2d_5 (MaxPoolin  (32, 1, 1, 72)            0
#  g2D)
#
#  flatten (Flatten)           (32, 72)                  0
#
#  dense (Dense)               (32, 72)                  5256
#
#  dense_1 (Dense)             (32, 7)                   511
#
# =================================================================
# Total params: 236015 (921.93 KB)
# Trainable params: 236015 (921.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.8821 - accuracy: 0.2852 - val_loss: 1.8818 - val_accuracy: 0.2812
# Epoch 2/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.7994 - accuracy: 0.3594 - val_loss: 1.9526 - val_accuracy: 0.2812
# Epoch 3/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.7894 - accuracy: 0.3594 - val_loss: 1.9316 - val_accuracy: 0.2812
# Epoch 4/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.8009 - accuracy: 0.3594 - val_loss: 1.8141 - val_accuracy: 0.2812
# Epoch 5/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.7582 - accuracy: 0.3594 - val_loss: 1.8659 - val_accuracy: 0.2812
# Epoch 6/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.7436 - accuracy: 0.3594 - val_loss: 1.7483 - val_accuracy: 0.2812
# Epoch 7/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.7388 - accuracy: 0.3594 - val_loss: 1.7242 - val_accuracy: 0.2812
# Epoch 8/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.6992 - accuracy: 0.3594 - val_loss: 1.7019 - val_accuracy: 0.2812
# Epoch 9/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.7008 - accuracy: 0.3594 - val_loss: 1.7604 - val_accuracy: 0.2812
# Epoch 10/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.6744 - accuracy: 0.3594 - val_loss: 1.6985 - val_accuracy: 0.3125
# Epoch 11/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.6481 - accuracy: 0.3789 - val_loss: 1.6370 - val_accuracy: 0.3438
# Epoch 12/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.6300 - accuracy: 0.3984 - val_loss: 1.6228 - val_accuracy: 0.3438
# Epoch 13/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5879 - accuracy: 0.4336 - val_loss: 1.5880 - val_accuracy: 0.3438
# Epoch 14/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5463 - accuracy: 0.4258 - val_loss: 1.6581 - val_accuracy: 0.3438
# Epoch 15/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5050 - accuracy: 0.4258 - val_loss: 1.6858 - val_accuracy: 0.4375
# Epoch 16/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5332 - accuracy: 0.4141 - val_loss: 1.4664 - val_accuracy: 0.3750
# Epoch 17/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4854 - accuracy: 0.4727 - val_loss: 1.7538 - val_accuracy: 0.3750
# Epoch 18/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5136 - accuracy: 0.4492 - val_loss: 1.5045 - val_accuracy: 0.4062
# Epoch 19/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4281 - accuracy: 0.4727 - val_loss: 1.5364 - val_accuracy: 0.3125
# Epoch 20/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4234 - accuracy: 0.4648 - val_loss: 1.4750 - val_accuracy: 0.3750
# Epoch 21/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4599 - accuracy: 0.4648 - val_loss: 1.5182 - val_accuracy: 0.3750
# Epoch 22/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.4533 - accuracy: 0.4688 - val_loss: 1.5997 - val_accuracy: 0.3438
# Epoch 23/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.3611 - accuracy: 0.4961 - val_loss: 1.6626 - val_accuracy: 0.3750
# Epoch 24/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.4109 - accuracy: 0.4922 - val_loss: 1.6305 - val_accuracy: 0.4062
# Epoch 25/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.3394 - accuracy: 0.4961 - val_loss: 1.4691 - val_accuracy: 0.3750
# Epoch 26/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.3442 - accuracy: 0.5469 - val_loss: 1.4308 - val_accuracy: 0.4062
# Epoch 27/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.3781 - accuracy: 0.4727 - val_loss: 1.6157 - val_accuracy: 0.4062
# Epoch 28/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2788 - accuracy: 0.5234 - val_loss: 1.6736 - val_accuracy: 0.3750
# Epoch 29/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2517 - accuracy: 0.5234 - val_loss: 1.5182 - val_accuracy: 0.4062
# Epoch 30/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2451 - accuracy: 0.5234 - val_loss: 1.5755 - val_accuracy: 0.3438
# Epoch 31/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2301 - accuracy: 0.5078 - val_loss: 1.4460 - val_accuracy: 0.3750
# Epoch 32/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2191 - accuracy: 0.5195 - val_loss: 1.5619 - val_accuracy: 0.3750
# Epoch 33/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1944 - accuracy: 0.5391 - val_loss: 1.6033 - val_accuracy: 0.3438
# Epoch 34/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1594 - accuracy: 0.5742 - val_loss: 1.5640 - val_accuracy: 0.5000
# Epoch 35/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1685 - accuracy: 0.5312 - val_loss: 1.5918 - val_accuracy: 0.4062
# Epoch 36/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1829 - accuracy: 0.5703 - val_loss: 1.4941 - val_accuracy: 0.4375
# Epoch 37/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.2353 - accuracy: 0.5391 - val_loss: 1.5618 - val_accuracy: 0.3438
# Epoch 38/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.2662 - accuracy: 0.5117 - val_loss: 1.4793 - val_accuracy: 0.4375
# Epoch 39/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.2165 - accuracy: 0.5391 - val_loss: 1.2341 - val_accuracy: 0.5312
# Epoch 40/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.2446 - accuracy: 0.5547 - val_loss: 1.3356 - val_accuracy: 0.3750
# Epoch 41/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.2622 - accuracy: 0.5273 - val_loss: 1.3922 - val_accuracy: 0.3750
# Epoch 42/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.1579 - accuracy: 0.5547 - val_loss: 1.4294 - val_accuracy: 0.4062
# Epoch 43/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.1453 - accuracy: 0.5742 - val_loss: 1.4778 - val_accuracy: 0.4062
# Epoch 44/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.0987 - accuracy: 0.5781 - val_loss: 1.3990 - val_accuracy: 0.4375
# Epoch 45/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.0427 - accuracy: 0.5703 - val_loss: 1.5426 - val_accuracy: 0.4062
# Epoch 46/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.0859 - accuracy: 0.5664 - val_loss: 1.5661 - val_accuracy: 0.4688
# Epoch 47/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.0007 - accuracy: 0.6289 - val_loss: 1.3667 - val_accuracy: 0.4688
# Epoch 48/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0626 - accuracy: 0.6250 - val_loss: 1.4400 - val_accuracy: 0.5000
# Epoch 49/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.0493 - accuracy: 0.6094 - val_loss: 1.4174 - val_accuracy: 0.4688
# Epoch 50/50

# %%
scores = model.evaluate(test_ds)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %%
model_version=1
model.save(f"../models/{model_version}")
